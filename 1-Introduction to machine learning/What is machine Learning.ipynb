# %% [markdown]
# ### What is Machine Learning

# %% [markdown]
# **what we lack in knowledge we make up for in data**

# %% [markdown]
# Machine Learning is the field of study that gives machine(computer) the capabilty to learn themself without being eplicitly programmed .

# %% [markdown]
# ML is an application of Artificial intelligence that provide system the ability to learn automatically and improve from experience without being explicitely programmed
#
# Machine works on simple concept
# -
# - Understanding with experience

# %% [markdown]
# ## Types of machine learning models
#
# - predictive - make prediction on the future
#
# - descriptive - gain knowledge from the data

# %% [markdown]
# **Predictive Analytics** It  will help an organization to know what might happen next, it predicts future based on present data available. It will analyze the data and provide statements that have not happened yet. It makes all kinds of predictions that you want to know and all predictions are probabilistic in nature.
#
# **Descriptive Analytics** will help an organization to know what has happened in the past, it would give you the past analytics using the data that are stored. For a company, it is necessary to know the past events that help them to make decisions based on the statistics using historical data. For example, you might want to know how much money you lost due to fraud and many more.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
